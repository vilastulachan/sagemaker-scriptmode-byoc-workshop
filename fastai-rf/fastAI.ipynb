# %% [markdown]
# ### Bring Your Own Container (BYOC)
#
# In this notebook, we will cover how to bring our own container with either a framework or algorithm to train a model on SageMaker.
#
# We will use fastai in this case and build our container with custom training code integrated into the container. The other option is to use script mode which is easily done by changing the entrypoint.
#
# Outline:
# 1. Build your own docker container with fastai framework
# 2. Register your docker container to Elastic Container Registry (ECR)
# 3. Use your docker container and prepared data to train your model

# %% [markdown]
# #### Container Image
# Let's start with building a container image locally and then push that to ECR (Elastic Container Registry)

# %%
# %cd docker
# Out:
# /home/ec2-user/SageMaker/pssummitwkshp/byoc/docker

# %%
# !docker build -t fastai .
# Out:
# Sending build context to Docker daemon  6.656kB
# Step 1/8 : FROM fastdotai/fastai:latest
# latest: Pulling from fastdotai/fastai
#
# 55322776: Pulling fs layer
# 02cb4e21: Pulling fs layer
# b1d03d39: Pulling fs layer
# e659dcd9: Pulling fs layer
# 93dd13fb: Pulling fs layer
# 51f98875: Pulling fs layer
# 47da6bdc: Pulling fs layer
# e1ed0a6f: Pulling fs layer
# e271bff3: Pulling fs layer
# b700ef54: Pulling fs layer
# 3c0e6050: Pulling fs layer
# d68ecf74: Pulling fs layer
# f559d1a8: Pulling fs layer
# 6a4fe0a9: Pulling fs layer
# Digest: sha256:a45d4490db48b3eac939d91b46e13c7480bc7e49359cc8875120e9858b7f107bDownloading  424.7MB/719.6MBDownloading  1.045GB/2.962GBDownloading  1.051GB/2.962GBExtracting  254.6MB/2.962GBExtracting  1.186GB/2.962GBExtracting  2.137GB/2.962GBExtracting  2.902GB/2.962GB
# Status: Downloaded newer image for fastdotai/fastai:latest
#  ---> 5e12d2f6fee1
# Step 2/8 : LABEL maintainer="Raj Kadiyala"
#  ---> Running in dd914707e7b5
# Removing intermediate container dd914707e7b5
#  ---> 4a6f33c01ea7
# Step 3/8 : WORKDIR /
#  ---> Running in 52e2d799fbeb
# Removing intermediate container 52e2d799fbeb
#  ---> 5fc974e7ceeb
# Step 4/8 : RUN pip3 install --no-cache --upgrade requests
#  ---> Running in c31d335e5260
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (2.25.1)
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests) (2.10)
# Installing collected packages: charset-normalizer, requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed charset-normalizer-2.0.7 requests-2.26.0
# Removing intermediate container c31d335e5260
#  ---> f62d171626d1
# Step 5/8 : ENV PYTHONDONTWRITEBYTECODE=1     PYTHONUNBUFFERED=1     LD_LIBRARY_PATH="${LD_LIBRARY_PATH}:/usr/local/lib"     PYTHONIOENCODING=UTF-8     LANG=C.UTF-8     LC_ALL=C.UTF-8
#  ---> Running in d065ca970f16
# Removing intermediate container d065ca970f16
#  ---> 538de4939014
# Step 6/8 : RUN pip3 install --no-cache --upgrade     sagemaker-training
#  ---> Running in 921e8c10ad61
# Collecting sagemaker-training
#   Downloading sagemaker_training-4.0.0.tar.gz (49 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (1.21.2)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (1.20.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (1.16.0)
# Requirement already satisfied: pip in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (21.0.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Collecting gevent
#   Downloading gevent-21.8.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.8 MB)
# Collecting inotify_simple==1.2.1
#   Downloading inotify_simple-1.2.1.tar.gz (7.9 kB)
# Requirement already satisfied: werkzeug>=0.15.5 in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (2.0.2)
# Collecting paramiko>=2.4.2
#   Downloading paramiko-2.8.0-py2.py3-none-any.whl (206 kB)
# Requirement already satisfied: psutil>=5.6.7 in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (5.8.0)
# Requirement already satisfied: protobuf>=3.1 in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (3.19.1)
# Requirement already satisfied: scipy>=1.2.2 in /opt/conda/lib/python3.7/site-packages (from sagemaker-training) (1.7.2)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.7/site-packages (from paramiko>=2.4.2->sagemaker-training) (3.4.8)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
# Requirement already satisfied: cffi>=1.1 in /opt/conda/lib/python3.7/site-packages (from bcrypt>=3.1.3->paramiko>=2.4.2->sagemaker-training) (1.14.6)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4.2->sagemaker-training) (2.20)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from boto3->sagemaker-training) (0.10.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.6 in /opt/conda/lib/python3.7/site-packages (from boto3->sagemaker-training) (1.23.6)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from boto3->sagemaker-training) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore<1.24.0,>=1.23.6->boto3->sagemaker-training) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.7/site-packages (from botocore<1.24.0,>=1.23.6->boto3->sagemaker-training) (1.26.6)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from gevent->sagemaker-training) (58.0.4)
# Collecting greenlet<2.0,>=1.1.0
#   Downloading greenlet-1.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (150 kB)
# Building wheels for collected packages: sagemaker-training, inotify-simple, retrying
#   Building wheel for sagemaker-training (setup.py): started
#   Building wheel for sagemaker-training (setup.py): finished with status 'done'
#   Created wheel for sagemaker-training: filename=sagemaker_training-4.0.0-cp37-cp37m-linux_x86_64.whl size=76111 sha256=c3b5b1dff525a5b26391b8d0261005904be6860bf3c1672a1e416c0776bce225
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nyi2tj9g/wheels/29/73/d0/ed39f4a73cfde1437b6d005bcdd5902b61500f3b2f077f3503
#   Building wheel for inotify-simple (setup.py): started
#   Building wheel for inotify-simple (setup.py): finished with status 'done'
#   Created wheel for inotify-simple: filename=inotify_simple-1.2.1-py3-none-any.whl size=8219 sha256=4173533b0f1edfb19be27af61f7f908ebf6f97b98780536db83e5e99e04f3ca2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nyi2tj9g/wheels/ef/7e/4a/bfeb3216a60ab5e077958f5a1e980cc3de9663155cfb31c660
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=2887b067f122d8bc68122fbc1ef4662ea9d6f778f531cd09b7cd0cfa0b025417
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nyi2tj9g/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built sagemaker-training inotify-simple retrying
# Installing collected packages: zope.interface, zope.event, pynacl, greenlet, bcrypt, retrying, paramiko, inotify-simple, gevent, sagemaker-training
# Successfully installed bcrypt-3.2.0 gevent-21.8.0 greenlet-1.1.2 inotify-simple-1.2.1 paramiko-2.8.0 pynacl-1.4.0 retrying-1.3.3 sagemaker-training-4.0.0 zope.event-4.5.0 zope.interface-5.4.0
# Removing intermediate container 921e8c10ad61
#  ---> 62d8290fad1d
# Step 7/8 : COPY code/* /opt/ml/code/
#  ---> 99c261a54e59
# Step 8/8 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Running in d32876725231
# Removing intermediate container d32876725231
#  ---> 23cced0fcdc8
# Successfully built 23cced0fcdc8
# Successfully tagged fastai:latest

# %% [markdown]
# Add docker images architecture to explain what is going on
# show the Dockerfile

# %%
# !docker images
# Out:
# REPOSITORY         TAG       IMAGE ID       CREATED         SIZE
# fastai             latest    23cced0fcdc8   8 seconds ago   8.25GB
# fastdotai/fastai   latest    5e12d2f6fee1   9 hours ago     8.22GB

# %% [markdown]
# ## Set the ecr details and tags
# Lets set a few params here like ecr name space , tag name etc.

# %%
from sagemaker import get_execution_role
import boto3
ecr_namespace = "sagemaker-training-containers/"
prefix = "script-mode-container-fastai"

ecr_repository_name = ecr_namespace + prefix
role = get_execution_role()
account_id = role.split(":")[4]
region = boto3.Session().region_name
tag_name=account_id+'.dkr.ecr.'+region+'.amazonaws.com/'+ecr_repository_name+':latest'

# %%
tag_name
# Out:
# '406078665760.dkr.ecr.us-west-2.amazonaws.com/sagemaker-training-containers/script-mode-container-fastai:latest'

# %%
# !docker tag fastai $tag_name

# %% [markdown]
# ### ECR Repository and push steps
#
# All of these can be scripted out but they are laid out this way for transparency and step evolution understanding

# %%
# !$(aws ecr get-login --no-include-email)
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !aws ecr create-repository --repository-name $ecr_repository_name
# Out:
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-west-2:406078665760:repository/sagemaker-training-containers/script-mode-container-fastai",
#         "registryId": "406078665760",
#         "repositoryName": "sagemaker-training-containers/script-mode-container-fastai",
#         "repositoryUri": "406078665760.dkr.ecr.us-west-2.amazonaws.com/sagemaker-training-containers/script-mode-container-fastai",
#         "createdAt": 1637076037.0,
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": false
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }

# %%
# !docker push $tag_name
# Out:
# The push refers to repository [406078665760.dkr.ecr.us-west-2.amazonaws.com/sagemaker-training-containers/script-mode-container-fastai]
#
# 6fa1c0ed: Preparing
# bccc2365: Preparing
# 27f41bbe: Preparing
# 937049be: Preparing
# 9e58289c: Preparing
# 35851702: Preparing
# 8ee652fb: Preparing
# 6e590844: Preparing
# bf18a086: Preparing
# 2f7b7495: Preparing
# a5c5c23f: Preparing
# a0a7e853: Preparing
# 4fc1cff8: Preparing
# 8b8f01e0: Preparing
# 1b69538d: Preparing
# fcbe6a14: Preparing
# 0881ce19: Preparing
# fcbe6a14: Pushed   6.197GB/6.162GBPushing  5.025MB/28.34MBPushing    487MB/6.162GBPushing  2.673GB/6.162GBPushing  3.135GB/6.162GBPushing  3.335GB/6.162GBPushing   3.54GB/6.162GBPushing  4.708GB/6.162GBPushing  4.855GB/6.162GBPushing  4.866GB/6.162GBPushing  5.104GB/6.162GBPushing  5.116GB/6.162GBPushing  5.154GB/6.162GBPushing  5.966GB/6.162GBPushing   6.05GB/6.162GBlatest: digest: sha256:43ae68fc1ffdf3ff9cd8e9297f9506de27fbe676c3f138a3ce51572438a1da35 size: 4295

# %%
container_image_uri = "{0}.dkr.ecr.{1}.amazonaws.com/{2}:latest".format( account_id, region, ecr_repository_name)
print(container_image_uri)
# Out:
# 406078665760.dkr.ecr.us-west-2.amazonaws.com/sagemaker-training-containers/script-mode-container-fastai:latest

# %%
# !aws s3 ls s3://rkadiy-data-bucket/train
# Out:
# An error occurred (NoSuchBucket) when calling the ListObjectsV2 operation: The specified bucket does not exist

# %% [markdown]
# #### Call your custom container to train the model

# %%
import sagemaker
import json

# JSON encode hyperparameters
def json_encode_hyperparameters(hyperparameters):
    return {str(k): json.dumps(v) for (k, v) in hyperparameters.items()}


hyperparameters = json_encode_hyperparameters({"lr":1e-03})

est = sagemaker.estimator.Estimator(
    container_image_uri,
    role,
    instance_count=1,
    #train_instance_type="local",  # we use local mode
    instance_type='ml.m5.4xlarge',
    base_job_name=prefix,
    hyperparameters=hyperparameters,
)

train_config = sagemaker.session.TrainingInput('s3://rkadiy-data-bucket/train')

est.fit({"train": train_config})
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-11-4ae241138c17> in <module>
#      21 train_config = sagemaker.session.TrainingInput('s3://rkadiy-data-bucket/train')
#      22
# ---> 23 est.fit({"train": train_config})
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     687         self._prepare_for_training(job_name=job_name)
#     688
# --> 689         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     690         self.jobs.append(self.latest_training_job)
#     691         if wait:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1466         """
#    1467         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1468         estimator.sagemaker_session.train(**train_args)
#    1469
#    1470         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config, environment, retry_strategy)
#     583         LOGGER.info("Creating training-job with name: %s", job_name)
#     584         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 585         self.sagemaker_client.create_training_job(**train_request)
#     586
#     587     def _get_train_request(  # noqa: C901
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     386                     "%s() only accepts keyword arguments." % py_operation_name)
#     387             # The "self" in this scope is referring to the BaseClient.
# --> 388             return self._make_api_call(operation_name, kwargs)
#     389
#     390         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     706             error_code = parsed_response.get("Error", {}).get("Code")
#     707             error_class = self.exceptions.from_code(error_code)
# --> 708             raise error_class(parsed_response, operation_name)
#     709         else:
#     710             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the CreateTrainingJob operation: No S3 objects found under S3 URL "s3://rkadiy-data-bucket/train" given in input data source. Please ensure that the bucket exists in the selected region (us-west-2), that objects exist under that S3 prefix, and that the role "arn:aws:iam::406078665760:role/SageMakerRepoRole" has "s3:ListBucket" permissions on bucket "rkadiy-data-bucket". Error message from S3: The specified bucket does not exist
